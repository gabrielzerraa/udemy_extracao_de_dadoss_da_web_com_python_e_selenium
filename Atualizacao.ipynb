# %% [markdown]
# # Importação das Bibliotecas

# %%
#!pip install selenium -q
#!pip install webdriver-manager -q

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

# Baixar o driver do chrome
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager

# %% [markdown]
# # TESTE

# %%
# Drive do Chrome
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

# %%
# Retornar depois de entender sobre IFRAMES
#driver.get('https://www.infomoney.com.br/')
#time.sleep(2)
#dados1 = driver.find_element(By.CLASS, "text-sm").find_element(By.TAG_NAME, "table")
#time.sleep(2)
#print(dados1)

# %%
driver.get('https://www.clubefii.com.br/fundos_imobiliarios_ranking')
time.sleep(2)
dados2 =  driver.find_element(By.TAG_NAME,"table").text
time.sleep(2)
print(dados2)
# Out:
# CÓDIGO
# NOME VARIAÇÃO COTA
# DESDE IPO
# VARIAÇÃO COTA + PROVENTOS
# DESDE IPO
#  ▴
# P/VPA YIELD
# 1 MES
# YIELD
# 12 MESES
# FEED
# HGPO11 Pátria Prime Offices +32,98% +392,87%
# 0,85
# 0,00% 108,06%
# HTMX11 Hotel Maxinvest +43,62% +383,11%
# 0,99
# 0,68% 17,93%
# HGBS11 Hedge Brasil Shopping +88,16% +352,60%
# 0,87
# 0,85% 10,52%
# RCRB11 Rio Bravo Renda Corporativa +18,39% +257,77%
# 0,59
# 0,72% 9,55%
# HGLG11 Pátria Log +51,91% +217,88%
# 0,93
# 0,72% 8,69%
# HGRE11 Pátria Escritórios +7,40% +193,82%
# 0,70
# 0,79% 9,52%
# KNRI11 Kinea Renda Imobiliária +36,39% +179,78%
# 0,85
# 0,73% 8,80%
# HGCR11 Pátria Recebiveis Imobiliários -5,12% +158,24%
# 0,99
# 1,11% 12,23%
# BTCI11 BTG Pactual Crédito Imobiliário -20,26% +150,00%
# 0,90
# 1,05% 12,48%
# VRTA11 Fator Verità -20,73% +143,66%
# 0,91
# 1,07% 12,93%
# MFII11 Mérito Desenvolvimento Imobiliário I -17,16% +137,42%
# 0,80
# 1,34% 17,04%
# TVRI11 Tivio Renda Imobiliária -9,41% +127,18%
# 0,89
# 1,14% 13,05%
# ...

# %%
driver.get(
